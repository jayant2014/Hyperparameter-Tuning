# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read data file
car_df = pd.read_csv("used_car_price.csv")

# %%
car_df.head()
# Out:
#     Make           Model   Type Origin DriveTrain   MSRP  EngineSize  \
# 0  Acura             MDX    SUV   Asia        All  36945         3.5
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  23820         2.0
# 2  Acura         TSX 4dr  Sedan   Asia      Front  26990         2.4
# 3  Acura          TL 4dr  Sedan   Asia      Front  33195         3.2
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  43755         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0          6         265        17           23    4451        106     189
# 1          4         200        24           31    2778        101     172
# 2          4         200        22           29    3230        105     183
# 3          6         270        20           28    3575        108     186
# 4          6         225        18           24    3880        115     197

# %%
# Let's perform One-Hot Encoding for categorical features lie Make, Model, Type, Origin, and DriveTrain
car_df = pd.get_dummies(car_df, columns=["Make", "Model", "Type", "Origin", "DriveTrain"])

# %%
car_df
# Out:
#       MSRP  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0    36945         3.5          6         265        17           23    4451
# 1    23820         2.0          4         200        24           31    2778
# 2    26990         2.4          4         200        22           29    3230
# 3    33195         3.2          6         270        20           28    3575
# 4    43755         3.5          6         225        18           24    3880
# ..     ...         ...        ...         ...       ...          ...     ...
# 423  40565         2.4          5         197        21           28    3450
# 424  42565         2.3          5         242        20           26    3450
# 425  45210         2.9          6         268        19           26    3653
# 426  26135         1.9          4         170        22           29    2822
# 427  35145         2.5          5         208        20           27    3823
#
#      Wheelbase  Length  Make_Acura  ...  Type_Sedan  Type_Sports  Type_Truck  \
# 0          106     189           1  ...           0            0           0
# 1          101     172           1  ...           1            0           0
# 2          105     183           1  ...           1            0           0
# 3          108     186           1  ...           1            0           0
# 4          115     197           1  ...           1            0           0
# ..         ...     ...         ...  ...         ...          ...         ...
# 423        105     186           0  ...           1            0           0
# 424        105     186           0  ...           1            0           0
# 425        110     190           0  ...           1            0           0
# 426        101     180           0  ...           0            0           0
# 427        109     186           0  ...           0            0           0
#
#      Type_Wagon  Origin_Asia  Origin_Europe  Origin_USA  DriveTrain_All  \
# 0             0            1              0           0               1
# 1             0            1              0           0               0
# 2             0            1              0           0               0
# 3             0            1              0           0               0
# 4             0            1              0           0               0
# ..          ...          ...            ...         ...             ...
# 423           0            0              1           0               0
# 424           0            0              1           0               0
# 425           0            0              1           0               0
# 426           1            0              1           0               0
# 427           1            0              1           0               1
#
#      DriveTrain_Front  DriveTrain_Rear
# 0                   0                0
# 1                   1                0
# 2                   1                0
# 3                   1                0
# 4                   1                0
# ..                ...              ...
# 423                 1                0
# 424                 1                0
# 425                 1                0
# 426                 1                0
# 427                 0                0
#
# [428 rows x 484 columns]

# %%
# Feeding input features to X and output (MSRP) to y
X = car_df.drop("MSRP", axis = 1)
y = car_df["MSRP"]

# %%
X = np.array(X)

# %%
y = np.array(y)

# %%
# Doing a train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (342, 483)

# %%
X_test.shape
# Out:
# (86, 483)

# %% [markdown]
# ### Applying XGBoost Without Optimization

# %%
import xgboost as xgb
model = xgb.XGBRegressor(objective ='reg:squarederror', learning_rate = 1, max_depth = 3, n_estimators = 500)
model.fit(X_train, y_train)

# predict the score of the trained model using the testing dataset
result = model.score(X_test, y_test)
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# RMSE = 7936.377
# R2 = 0.7957875034739448

# %% [markdown]
# ### XGBoost With Grid Search Optimization

# %%
from sklearn.model_selection import GridSearchCV
parameters_grid = { 'max_depth': [3, 10, 20], 
                   'learning_rate': [0.1, 0.5, 1],
                   'n_estimators': [100, 500],
                   'colsample_bytree': [0.3, 0.7]}

model = xgb.XGBRegressor(objective ='reg:squarederror')

xgb_gridsearch = GridSearchCV(estimator = model, 
                              param_grid = parameters_grid, 
                              scoring = 'neg_mean_squared_error',  
                              cv = 5, 
                              verbose = 5)

xgb_gridsearch.fit(X_train, y_train)
y_predict = xgb_gridsearch.predict(X_test)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=
total time=   1.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=-99333205.009 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=-167480783.078 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=-29671891.960 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=-91132866.298 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=-50505453.624 total time=   7.0s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=-99333233.749 total time=   6.8s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=-167480777.955 total time=   7.4s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=-29671887.032 total time=   7.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=-91132923.274 total time=   7.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=100;, score=-58920967.001 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=100;, score=-100534741.710 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=100;, score=-189513444.201 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=100;, score=-24072318.248 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=100;, score=-105549934.650 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=500;, score=-58483618.393 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=500;, score=-100952607.076 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=500;, score=-189354595.055 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=500;, score=-23599411.149 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=3, n_estimators=500;, score=-105861158.207 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=100;, score=-103727264.309 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=100;, score=-121122610.255 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=100;, score=-267145268.540 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=100;, score=-27814041.779 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=100;, score=-134274848.210 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=500;, score=-103727257.666 total time=   1.5s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=500;, score=-121122610.194 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=500;, score=-267145267.195 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=500;, score=-27814014.460 total time=   2.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=10, n_estimators=500;, score=-134274844.688 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=100;, score=-120358238.071 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=100;, score=-116894567.301 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=100;, score=-268046170.650 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=100;, score=-25042765.065 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=100;, score=-140184722.774 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=500;, score=-120358238.071 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=500;, score=-116894567.301 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=500;, score=-268046170.650 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=500;, score=-25042765.065 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=1, max_depth=20, n_estimators=500;, score=-140184722.774 total time=   1.3s

# %%
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# RMSE = 4897.023
# R2 = 0.9222497221060714

# %% [markdown]
# ### XGBoost With Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

grid = {
    'n_estimators': [100, 500],
    'max_depth': [3, 10, 20],
    'learning_rate': [0.1, 0.5], 
    'colsample_bytree': [0.3, 0.7]}


import xgboost as xgb
model = xgb.XGBRegressor(objective ='reg:squarederror')

random_cv = RandomizedSearchCV(estimator = model,
                               param_distributions = grid,
                               cv = 5, 
                               n_iter = 100,
                               scoring = 'neg_mean_absolute_error',
                               verbose = 5, 
                               return_train_score = True)
random_cv.fit(X_train, y_train)

random_cv.best_estimator_
y_predict = random_cv.predict(X_test)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\users\jayan\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_search.py:289: UserWarning: The total space of parameters 24 is smaller than n_iter=100. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2732.912, test=-4270.703) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2495.782, test=-4787.527) total time=   0.2s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2593.123, test=-4918.865) total time=   0.2s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2700.076, test=-3700.005) total time=   0.2s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2490.215, test=-4627.835) total time=   0.3s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1206.932, test=-3785.480) total time=   1.4s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1171.053, test=-4483.688) total time=   1.1s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1074.646, test=-4411.057) total time=   1.1s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1127.558, test=-3331.275) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1173.076, test=-4343.563) total time=   0.9s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-270.557, test=-4231.204) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-347.008, test=-4848.472) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-339.443, test=-4822.024) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-308.081, test=-3170.549) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-288.394, test=-4348.150) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-17.002, test=-4198.539) total time=   2.5s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-37.319, test=-4797.333) total time=   2.3s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-30.565, test=-4775.562) total time=   2.9s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-26.857, test=-3112.112) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-24.536, test=-4356.962) total time=   3.3s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-62.124, test=-4316.217) total time=   0.9s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-75.967, test=-4877.332) total time=   1.1s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-69.688, test=-4896.698) total time=   1.0s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-63.298, test=-3210.558) total time=   1.2s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-74.434, test=-4431.244) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.013, test=-4314.844) total time=   5.3s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.044, test=-4874.177) total time=   5.4s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.013, test=-4893.891) total time=   6.3s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.012, test=-3198.241) total time=   5.6s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.015, test=-4445.200) total time=   5.5s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1052.561, test=-4472.228) total time=   0.2s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1102.717, test=-4880.346) total time=   0.2s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1142.167, test=-5202.650) total time=   0.2s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1231.567, test=-3867.147) total time=   0.2s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1134.212, test=-5004.321) total time=   0.2s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-100.780, test=-4377.532) total time=   1.2s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-106.083, test=-4860.433) total time=   1.0s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-127.399, test=-5137.533) total time=   0.9s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-100.396, test=-3622.176) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-111.684, test=-5033.934) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-21.382, test=-5036.685) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-30.167, test=-5849.040) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-31.096, test=-5674.536) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-26.952, test=-3607.988) total time=   0.6s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-17.511, test=-5274.503) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-5034.796) total time=   3.0s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-5848.003) total time=   2.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-5670.935) total time=   2.5s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-3605.703) total time=   2.5s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-5275.029) total time=   2.5s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.005, test=-5325.866) total time=   1.2s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.006, test=-6272.397) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.002, test=-5450.259) total time=   1.2s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.003, test=-3572.439) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.003, test=-5320.438) total time=   1.2s
# [CV 1/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.000, test=-5325.860) total time=   4.7s
# [CV 2/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-6272.393) total time=   5.0s
# [CV 3/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-5450.257) total time=   5.0s
# [CV 4/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.000, test=-3572.442) total time=   4.6s
# [CV 5/5] END colsample_bytree=0.3, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.000, test=-5320.435) total time=   4.7s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2583.328, test=-4078.480) total time=   0.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2522.822, test=-4986.141) total time=   0.2s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2379.272, test=-5021.319) total time=   0.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2607.368, test=-3670.031) total time=   0.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-2427.569, test=-4893.623) total time=   0.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1097.735, test=-3783.295) total time=   1.4s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1200.994, test=-4753.200) total time=   1.4s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1071.451, test=-4728.260) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1132.567, test=-3256.703) total time=   1.3s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500;, score=(train=-1146.325, test=-4624.785) total time=   1.3s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-265.688, test=-4117.818) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-230.372, test=-4660.322) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-207.078, test=-4746.806) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-265.412, test=-3072.613) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100;, score=(train=-219.930, test=-5608.860) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-15.908, test=-4085.034) total time=   3.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-21.373, test=-4630.866) total time=   3.7s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-17.597, test=-4708.430) total time=   3.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-19.634, test=-3030.949) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500;, score=(train=-16.227, test=-5553.060) total time=   3.9s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-34.265, test=-4433.215) total time=   1.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-31.317, test=-4792.282) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-32.906, test=-5105.304) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-35.115, test=-3110.498) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=100;, score=(train=-36.276, test=-5682.614) total time=   1.3s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.012, test=-4433.617) total time=   7.0s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.018, test=-4789.509) total time=   7.0s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.022, test=-5102.167) total time=   6.8s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.015, test=-3102.644) total time=   6.9s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.1, max_depth=20, n_estimators=500;, score=(train=-0.018, test=-5673.558) total time=   7.0s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1070.813, test=-4515.301) total time=   0.2s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-937.768, test=-5347.849) total time=   0.2s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1004.815, test=-4558.037) total time=   0.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-982.303, test=-3746.578) total time=   0.2s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=100;, score=(train=-1014.261, test=-4592.733) total time=   0.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-82.337, test=-4489.926) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-97.751, test=-5333.650) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-94.286, test=-4511.982) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-88.502, test=-3535.037) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=3, n_estimators=500;, score=(train=-76.280, test=-4517.232) total time=   1.3s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-12.461, test=-4666.059) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-12.889, test=-5290.943) total time=   0.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-13.061, test=-5632.079) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-10.934, test=-3842.089) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=100;, score=(train=-16.404, test=-5106.439) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.003, test=-4665.755) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.003, test=-5290.396) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.004, test=-5630.896) total time=   3.6s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-3842.911) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=10, n_estimators=500;, score=(train=-0.002, test=-5105.318) total time=   3.6s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.002, test=-4470.380) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.001, test=-5780.964) total time=   1.4s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.002, test=-5850.443) total time=   1.4s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.001, test=-3710.585) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=100;, score=(train=-0.003, test=-5279.375) total time=   1.2s
# [CV 1/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-4470.376) total time=   6.6s
# [CV 2/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-5780.966) total time=   6.9s
# [CV 3/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-5850.443) total time=   7.2s
# [CV 4/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-3710.585) total time=   6.8s
# [CV 5/5] END colsample_bytree=0.7, learning_rate=0.5, max_depth=20, n_estimators=500;, score=(train=-0.001, test=-5279.379) total time=   6.7s

# %%
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# RMSE = 4897.023
# R2 = 0.9222497221060714

# %% [markdown]
# ### XGBoost With Bayesian Optimization

# %%
from skopt import BayesSearchCV

search_space = {
        "max_depth": (4, 20, 'log-uniform'),
        "n_estimators": (2, 100, 'log-uniform'),
        'learning_rate': (0.01, 1.0, 'log-uniform')}            

model = xgb.XGBRegressor(objective ='reg:squarederror')

xgb_bayes_search = BayesSearchCV(model, 
                                    search_space, 
                                    n_iter = 100, 
                                    scoring = 'neg_mean_absolute_error', 
                                    cv = 5)

xgb_bayes_search.fit(X_train, y_train) 

y_predict = xgb_bayes_search.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)),'.3f'))
r2 = r2_score(y_test, y_predict)

print('RMSE =',RMSE,'\nR2 =', r2)
# Out:
# RMSE = 6240.85
# R2 = 0.8737227242321206

# %%
# From the above experiment GridSearch and RandomSearch provides better result with almost same performance.
